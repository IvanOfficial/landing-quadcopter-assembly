# %%
import cv2
import numpy as np
import glob
from tqdm import tqdm
import PIL.ExifTags
import PIL.Image
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from tqdm import tqdm


class calibrator:
    def __init__(self, number_cam, fl):
        self.number_cam = number_cam
        self.ret = None
        self.K = None
        self.dist = None
        self.rvecs = None
        self.tvecs = None
        self.focal_length = fl
        self.detected = None
        self.count = None
        self.line_to_images = './calibration_images/' + number_cam + '/*'
        self.line_to_params = "./camera_params/" + number_cam + "/"
        self.obj_points = None
        self.imagePoints1 = None
        self.gray_image_shape = None
        self.image_size = None
        self.detected_image_list = []
        self.line_to_images_new = './calibration_images/new/' + number_cam + '/*'

    def save_params(self):
        # Save parameters into numpy file
        line = self.line_to_params
        np.save(line + "ret", self.ret)
        np.save(line + "K", self.K)
        np.save(line + "dist", self.dist)
        np.save(line + "rvecs", self.rvecs)
        np.save(line + "tvecs", self.tvecs)
        np.save(line + "FocalLength", self.focal_length)

    def calibration_(self):
        # ============================================
        # Camera calibration
        # ============================================

        # Define size of chessboard target.

        chessboard_size = (6, 9)
        # chessboard_size = (7,5)
        # Define arrays to save detected points
        obj_points = []  # 3D points in real world space
        img_points = []  # 3D points in image plane

        # Prepare grid and points to display

        objp = np.zeros((np.prod(chessboard_size), 3), dtype=np.float32)

        objp[:, :2] = np.mgrid[0:chessboard_size[0], 0:chessboard_size[1]].T.reshape(-1, 2)

        # read images
        line = self.line_to_images_new
        calibration_paths = glob.glob(line)
        calibration_paths.sort()
        t = 0
        y = 0
        # Iterate over images to find intrinsic matrix
        #for image_path in tqdm_notebook(calibration_paths):
        print("Calibration ..." + "\n" + "camera: " + self.number_cam)
        for image_path in tqdm_notebook(calibration_paths):

            # Load image
            image = cv2.imread(image_path)
            gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            # print("Image loaded, Analizying...")
            # find chessboard corners
            # plt.imshow(gray_image)
            # plt.show()
            ret, corners = cv2.findChessboardCorners(gray_image, chessboard_size, None)

            if ret == True:
                # print("+++++++++++++++++Chessboard detected!+++++++++++++++++")
                # print(image_path)
                # define criteria for subpixel accuracy
                criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
                # refine corner location (to subpixel accuracy) based on criteria.
                cv2.cornerSubPix(gray_image, corners, (5, 5), (-1, -1), criteria)
                obj_points.append(objp)
                img_points.append(corners)
                self.detected_image_list.append(image_path)
                y += 1
            t += 1
        h, w = image.shape[:2]
        self.image_size = (h,w)
        self.detected = y
        self.count = t
        # Calibrate camera
        self.ret, self.K, self.dist, self.rvecs, self.tvecs = cv2.calibrateCamera(obj_points,
                                                                                  img_points,
                                                                                  gray_image.shape[::-1],
                                                                                  None, None)
        self.obj_points = obj_points
        self.img_points = img_points
        self.gray_image_shape = gray_image.shape[::-1]
        print("================ Calibration was successful  =================")

    def calibration_cam(self):
        self.calibration_()
        self.save_params()
        print("There were only images: " + str(self.count) + "\n" + "There were a total of images found: " + str(
            self.detected))


    def make_detected_image_list(self):

        # read images
        line = self.line_to_images
        calibration_paths = glob.glob(line)
        chessboard_size = (6, 9)
        print("Make detected_image_list, camera: " + self.number_cam)
        for image_path in tqdm(calibration_paths):

            # Load image
            image = cv2.imread(image_path)
            gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            ret, corners = cv2.findChessboardCorners(gray_image, chessboard_size, None)

            if ret == True:
                self.detected_image_list.append(image_path[len(self.line_to_images)-1:])



class stereo_calibrator:
    def __init__(self, number_cam_left, number_cam_right, fl_left, fl_right):
        self.number_cam_left = number_cam_left
        self.number_cam_right = number_cam_right
        self.link_to_recreate = './calibration_images/new/'
        self.calibrovka_left = calibrator(number_cam_left, fl_left)
        self.calibrovka_right = calibrator(number_cam_right, fl_right)

    def stereo_calibration_separately(self):
        self.calibrovka_left.calibration_cam()
        self.calibrovka_right.calibration_cam()


    def stereo_calibration_together(self):
        ret, K_left, dist_left, K_right, dist_right, R, T, E, F = cv2.stereoCalibrate(
            objectPoints=self.calibrovka_left.obj_points,
            imagePoints1=self.calibrovka_left.img_points,
            imagePoints2=self.calibrovka_right.img_points,
            cameraMatrix1=self.calibrovka_left.K,
            distCoeffs1=self.calibrovka_left.dist,
            cameraMatrix2=self.calibrovka_right.K,
            distCoeffs2=self.calibrovka_right.dist,
            imageSize=self.calibrovka_left.gray_image_shape)
        # see more obout this parameters : https://docs.opencv.org/2.4/modules/calib3d/doc/calib3d.html

        link = "./camera_params/stereo_params/"
        # Save parameters into numpy file
        np.save(link + "ret", ret)
        np.save(link + "K_left", K_left)
        np.save(link + "K_right", K_right)
        np.save(link + "dist_left", dist_left)
        np.save(link + "dist_right", dist_right)
        np.save(link + "R", R)
        np.save(link + "T", T)
        np.save(link + "E", E)
        np.save(link + "F", F)
        np.save(link + "image_size", self.calibrovka_left.image_size)
        print("================ Stereocalibration was successful  =================")

    def stereo_calibration(self):
    	self.selection()
    	self.stereo_calibration_separately()
    	self.stereo_calibration_together()
    	
    def re_create_data_images(self):
        ll = self.calibrovka_left.detected_image_list
        lr = self.calibrovka_right.detected_image_list
        print("Re-create data images")

        for l in tqdm(ll):
            if l in lr:
                
                image_left = cv2.imread(self.calibrovka_left.line_to_images[:-1] + l)
                image_right = cv2.imread(self.calibrovka_right.line_to_images[:-1] + l)
                cv2.imwrite(self.link_to_recreate + self.calibrovka_left.number_cam + '/' + l, image_left)
                cv2.imwrite(self.link_to_recreate + self.calibrovka_right.number_cam + '/' + l, image_right)

    def selection(self):
    	self.calibrovka_left.make_detected_image_list()
    	self.calibrovka_right.make_detected_image_list()
    	self.re_create_data_images()

# %%
name_left = "25797059"
name_right = "25791059"
calib = stereo_calibrator(name_left, name_right, 8, 8)

# %%
calib.stereo_calibration_separately()
# Out:
# Calibration ...
# camera: 25797059
# HBox(children=(IntProgress(value=0, max=299), HTML(value='')))

# %%
image = cv2.imread('./calibration_images/new/25797059/261.png')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
glob.glob(calib.calibrovka_left.line_to_images_new)
# Out:
# ['./calibration_images/new/25797059/261.png',
#  './calibration_images/new/25797059/14.png',
#  './calibration_images/new/25797059/74.png',
#  './calibration_images/new/25797059/211.png',
#  './calibration_images/new/25797059/240.png',
#  './calibration_images/new/25797059/80.png',
#  './calibration_images/new/25797059/19.png',
#  './calibration_images/new/25797059/120.png',
#  './calibration_images/new/25797059/79.png',
#  './calibration_images/new/25797059/297.png',
#  './calibration_images/new/25797059/12.png',
#  './calibration_images/new/25797059/115.png',
#  './calibration_images/new/25797059/140.png',
#  './calibration_images/new/25797059/61.png',
#  './calibration_images/new/25797059/268.png',
#  './calibration_images/new/25797059/86.png',
#  './calibration_images/new/25797059/147.png',
#  './calibration_images/new/25797059/44.png',
#  './calibration_images/new/25797059/247.png',
#  './calibration_images/new/25797059/264.png',
#  './calibration_images/new/25797059/173.png',
#  './calibration_images/new/25797059/226.png',
#  './calibration_images/new/25797059/251.png',
#  './calibration_images/new/25797059/15.png',
#  './calibration_images/new/25797059/92.png',
#  './calibration_images/new/25797059/69.png',
#  './calibration_images/new/25797059/237.png',
#  './calibration_images/new/25797059/51.png',
#  './calibration_images/new/25797059/214.png',
#  './calibration_images/new/25797059/294.png',
#  './calibration_images/new/25797059/49.png',
#  './calibration_images/new/25797059/151.png',
#  './calibration_images/new/25797059/27.png',
#  './calibration_images/new/25797059/269.png',
#  './calibration_images/new/25797059/193.png',
#  './calibration_images/new/25797059/168.png',
#  './calibration_images/new/25797059/178.png',
#  './calibration_images/new/25797059/71.png',
#  './calibration_images/new/25797059/218.png',
#  './calibration_images/new/25797059/21.png',
#  './calibration_images/new/25797059/159.png',
#  './calibration_images/new/25797059/65.png',
#  './calibration_images/new/25797059/206.png',
#  './calibration_images/new/25797059/145.png',
#  './calibration_images/new/25797059/207.png',
#  './calibration_images/new/25797059/172.png',
#  './calibration_images/new/25797059/107.png',
#  './calibration_images/new/25797059/110.png',
#  './calibration_images/new/25797059/116.png',
#  './calibration_images/new/25797059/26.png',
#  './calibration_images/new/25797059/62.png',
#  './calibration_images/new/25797059/87.png',
#  './calibration_images/new/25797059/88.png',
#  './calibration_images/new/25797059/10.png',
#  './calibration_images/new/25797059/275.png',
#  './calibration_images/new/25797059/143.png',
#  './calibration_images/new/25797059/227.png',
#  './calibration_images/new/25797059/45.png',
#  './calibration_images/new/25797059/295.png',
#  './calibration_images/new/25797059/267.png',
#  './calibration_images/new/25797059/289.png',
#  './calibration_images/new/25797059/165.png',
#  './calibration_images/new/25797059/141.png',
#  './calibration_images/new/25797059/259.png',
#  './calibration_images/new/25797059/149.png',
#  './calibration_images/new/25797059/83.png',
#  './calibration_images/new/25797059/166.png',
#  './calibration_images/new/25797059/94.png',
#  './calibration_images/new/25797059/63.png',
#  './calibration_images/new/25797059/135.png',
#  './calibration_images/new/25797059/183.png',
#  './calibration_images/new/25797059/103.png',
#  './calibration_images/new/25797059/160.png',
#  './calibration_images/new/25797059/196.png',
#  './calibration_images/new/25797059/263.png',
#  './calibration_images/new/25797059/265.png',
#  './calibration_images/new/25797059/163.png',
#  './calibration_images/new/25797059/43.png',
#  './calibration_images/new/25797059/144.png',
#  './calibration_images/new/25797059/216.png',
#  './calibration_images/new/25797059/1.png',
#  './calibration_images/new/25797059/137.png',
#  './calibration_images/new/25797059/279.png',
#  './calibration_images/new/25797059/52.png',
#  './calibration_images/new/25797059/28.png',
#  './calibration_images/new/25797059/228.png',
#  './calibration_images/new/25797059/76.png',
#  './calibration_images/new/25797059/8.png',
#  './calibration_images/new/25797059/182.png',
#  './calibration_images/new/25797059/126.png',
#  './calibration_images/new/25797059/22.png',
#  './calibration_images/new/25797059/242.png',
#  './calibration_images/new/25797059/95.png',
#  './calibration_images/new/25797059/210.png',
#  './calibration_images/new/25797059/84.png',
#  './calibration_images/new/25797059/198.png',
#  './calibration_images/new/25797059/235.png',
#  './calibration_images/new/25797059/85.png',
#  './calibration_images/new/25797059/239.png',
#  './calibration_images/new/25797059/0.png',
#  './calibration_images/new/25797059/219.png',
#  './calibration_images/new/25797059/260.png',
#  './calibration_images/new/25797059/34.png',
#  './calibration_images/new/25797059/299.png',
#  './calibration_images/new/25797059/187.png',
#  './calibration_images/new/25797059/156.png',
#  './calibration_images/new/25797059/250.png',
#  './calibration_images/new/25797059/46.png',
#  './calibration_images/new/25797059/176.png',
#  './calibration_images/new/25797059/213.png',
#  './calibration_images/new/25797059/223.png',
#  './calibration_images/new/25797059/270.png',
#  './calibration_images/new/25797059/3.png',
#  './calibration_images/new/25797059/38.png',
#  './calibration_images/new/25797059/130.png',
#  './calibration_images/new/25797059/179.png',
#  './calibration_images/new/25797059/186.png',
#  './calibration_images/new/25797059/32.png',
#  './calibration_images/new/25797059/181.png',
#  './calibration_images/new/25797059/155.png',
#  './calibration_images/new/25797059/17.png',
#  './calibration_images/new/25797059/271.png',
#  './calibration_images/new/25797059/4.png',
#  './calibration_images/new/25797059/278.png',
#  './calibration_images/new/25797059/100.png',
#  './calibration_images/new/25797059/57.png',
#  './calibration_images/new/25797059/252.png',
#  './calibration_images/new/25797059/189.png',
#  './calibration_images/new/25797059/133.png',
#  './calibration_images/new/25797059/245.png',
#  './calibration_images/new/25797059/55.png',
#  './calibration_images/new/25797059/167.png',
#  './calibration_images/new/25797059/273.png',
#  './calibration_images/new/25797059/91.png',
#  './calibration_images/new/25797059/231.png',
#  './calibration_images/new/25797059/171.png',
#  './calibration_images/new/25797059/6.png',
#  './calibration_images/new/25797059/192.png',
#  './calibration_images/new/25797059/108.png',
#  './calibration_images/new/25797059/217.png',
#  './calibration_images/new/25797059/158.png',
#  './calibration_images/new/25797059/67.png',
#  './calibration_images/new/25797059/53.png',
#  './calibration_images/new/25797059/197.png',
#  './calibration_images/new/25797059/109.png',
#  './calibration_images/new/25797059/248.png',
#  './calibration_images/new/25797059/106.png',
#  './calibration_images/new/25797059/285.png',
#  './calibration_images/new/25797059/276.png',
#  './calibration_images/new/25797059/33.png',
#  './calibration_images/new/25797059/203.png',
#  './calibration_images/new/25797059/180.png',
#  './calibration_images/new/25797059/287.png',
#  './calibration_images/new/25797059/56.png',
#  './calibration_images/new/25797059/201.png',
#  './calibration_images/new/25797059/96.png',
#  './calibration_images/new/25797059/98.png',
#  './calibration_images/new/25797059/134.png',
#  './calibration_images/new/25797059/2.png',
#  './calibration_images/new/25797059/16.png',
#  './calibration_images/new/25797059/128.png',
#  './calibration_images/new/25797059/274.png',
#  './calibration_images/new/25797059/303.png',
#  './calibration_images/new/25797059/188.png',
#  './calibration_images/new/25797059/66.png',
#  './calibration_images/new/25797059/48.png',
#  './calibration_images/new/25797059/253.png',
#  './calibration_images/new/25797059/302.png',
#  './calibration_images/new/25797059/222.png',
#  './calibration_images/new/25797059/292.png',
#  './calibration_images/new/25797059/290.png',
#  './calibration_images/new/25797059/246.png',
#  './calibration_images/new/25797059/200.png',
#  './calibration_images/new/25797059/105.png',
#  './calibration_images/new/25797059/5.png',
#  './calibration_images/new/25797059/150.png',
#  './calibration_images/new/25797059/256.png',
#  './calibration_images/new/25797059/70.png',
#  './calibration_images/new/25797059/254.png',
#  './calibration_images/new/25797059/142.png',
#  './calibration_images/new/25797059/127.png',
#  './calibration_images/new/25797059/119.png',
#  './calibration_images/new/25797059/114.png',
#  './calibration_images/new/25797059/90.png',
#  './calibration_images/new/25797059/152.png',
#  './calibration_images/new/25797059/208.png',
#  './calibration_images/new/25797059/131.png',
#  './calibration_images/new/25797059/169.png',
#  './calibration_images/new/25797059/104.png',
#  './calibration_images/new/25797059/174.png',
#  './calibration_images/new/25797059/122.png',
#  './calibration_images/new/25797059/81.png',
#  './calibration_images/new/25797059/99.png',
#  './calibration_images/new/25797059/124.png',
#  './calibration_images/new/25797059/257.png',
#  './calibration_images/new/25797059/164.png',
#  './calibration_images/new/25797059/293.png',
#  './calibration_images/new/25797059/194.png',
#  './calibration_images/new/25797059/281.png',
#  './calibration_images/new/25797059/25.png',
#  './calibration_images/new/25797059/123.png',
#  './calibration_images/new/25797059/78.png',
#  './calibration_images/new/25797059/266.png',
#  './calibration_images/new/25797059/117.png',
#  './calibration_images/new/25797059/29.png',
#  './calibration_images/new/25797059/64.png',
#  './calibration_images/new/25797059/20.png',
#  './calibration_images/new/25797059/229.png',
#  './calibration_images/new/25797059/93.png',
#  './calibration_images/new/25797059/291.png',
#  './calibration_images/new/25797059/283.png',
#  './calibration_images/new/25797059/73.png',
#  './calibration_images/new/25797059/50.png',
#  './calibration_images/new/25797059/59.png',
#  './calibration_images/new/25797059/129.png',
#  './calibration_images/new/25797059/170.png',
#  './calibration_images/new/25797059/136.png',
#  './calibration_images/new/25797059/258.png',
#  './calibration_images/new/25797059/162.png',
#  './calibration_images/new/25797059/215.png',
#  './calibration_images/new/25797059/232.png',
#  './calibration_images/new/25797059/230.png',
#  './calibration_images/new/25797059/23.png',
#  './calibration_images/new/25797059/102.png',
#  './calibration_images/new/25797059/296.png',
#  './calibration_images/new/25797059/284.png',
#  './calibration_images/new/25797059/18.png',
#  './calibration_images/new/25797059/146.png',
#  './calibration_images/new/25797059/262.png',
#  './calibration_images/new/25797059/199.png',
#  './calibration_images/new/25797059/138.png',
#  './calibration_images/new/25797059/13.png',
#  './calibration_images/new/25797059/221.png',
#  './calibration_images/new/25797059/36.png',
#  './calibration_images/new/25797059/111.png',
#  './calibration_images/new/25797059/272.png',
#  './calibration_images/new/25797059/47.png',
#  './calibration_images/new/25797059/39.png',
#  './calibration_images/new/25797059/224.png',
#  './calibration_images/new/25797059/175.png',
#  './calibration_images/new/25797059/7.png',
#  './calibration_images/new/25797059/148.png',
#  './calibration_images/new/25797059/288.png',
#  './calibration_images/new/25797059/139.png',
#  './calibration_images/new/25797059/241.png',
#  './calibration_images/new/25797059/113.png',
#  './calibration_images/new/25797059/243.png',
#  './calibration_images/new/25797059/31.png',
#  './calibration_images/new/25797059/35.png',
#  './calibration_images/new/25797059/202.png',
#  './calibration_images/new/25797059/11.png',
#  './calibration_images/new/25797059/244.png',
#  './calibration_images/new/25797059/121.png',
#  './calibration_images/new/25797059/40.png',
#  './calibration_images/new/25797059/89.png',
#  './calibration_images/new/25797059/300.png',
#  './calibration_images/new/25797059/209.png',
#  './calibration_images/new/25797059/157.png',
#  './calibration_images/new/25797059/154.png',
#  './calibration_images/new/25797059/238.png',
#  './calibration_images/new/25797059/30.png',
#  './calibration_images/new/25797059/153.png',
#  './calibration_images/new/25797059/118.png',
#  './calibration_images/new/25797059/195.png',
#  './calibration_images/new/25797059/212.png',
#  './calibration_images/new/25797059/286.png',
#  './calibration_images/new/25797059/233.png',
#  './calibration_images/new/25797059/177.png',
#  './calibration_images/new/25797059/236.png',
#  './calibration_images/new/25797059/191.png',
#  './calibration_images/new/25797059/58.png',
#  './calibration_images/new/25797059/225.png',
#  './calibration_images/new/25797059/42.png',
#  './calibration_images/new/25797059/298.png',
#  './calibration_images/new/25797059/82.png',
#  './calibration_images/new/25797059/190.png',
#  './calibration_images/new/25797059/9.png',
#  './calibration_images/new/25797059/280.png',
#  './calibration_images/new/25797059/41.png',
#  './calibration_images/new/25797059/301.png',
#  './calibration_images/new/25797059/54.png',
#  './calibration_images/new/25797059/77.png',
#  './calibration_images/new/25797059/24.png',
#  './calibration_images/new/25797059/184.png',
#  './calibration_images/new/25797059/282.png',
#  './calibration_images/new/25797059/132.png',
#  './calibration_images/new/25797059/249.png',
#  './calibration_images/new/25797059/125.png',
#  './calibration_images/new/25797059/68.png',
#  './calibration_images/new/25797059/204.png',
#  './calibration_images/new/25797059/185.png',
#  './calibration_images/new/25797059/255.png',
#  './calibration_images/new/25797059/37.png',
#  './calibration_images/new/25797059/234.png',
#  './calibration_images/new/25797059/205.png',
#  './calibration_images/new/25797059/72.png',
#  './calibration_images/new/25797059/220.png',
#  './calibration_images/new/25797059/97.png',
#  './calibration_images/new/25797059/75.png']
